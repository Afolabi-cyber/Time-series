# %% [markdown]
# # **TIME SERIES EDA**

# %%
#install Pandas Data Reader
! pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import yfinance as yf

# %%
df_tesla = yf.download('TSLA')
df_tesla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-03-11  175.449997  182.869995  174.800003  177.770004  177.770004
# 2024-03-12  177.770004  179.429993  172.410004  177.539993  177.539993
# 2024-03-13  173.050003  176.050003  169.149994  169.479996  169.479996
# 2024-03-14  167.770004  171.169998  160.509995  162.500000  162.500000
# 2024-03-15  163.160004  165.179993  160.759995  163.570007  163.570007
#
#                Volume
# Date
# ...

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.shape
# Out:
# (3452, 6)

# %%
df_tesla['High'].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#xlimit and ylimit
df_tesla['High'].plot(xlim=['2020-01-01', '2024-01-01'],figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#xlimit and ylimit
df_tesla['High'].plot(xlim=['2020-01-01', '2024-01-01'],ylim=[0, 400],figsize=(12,5),ls='--',color='g')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07',
#                '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Date', length=3452, freq=None)

# %%
df_tesla.head(4)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000

# %%
index = df_tesla.loc['2020-01-01':'2024-01-01'].index
stock_open = df_tesla.loc['2020-01-01':'2024-01-01']['Open']

# %%
stock_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2023-12-22    256.760010
# 2023-12-26    254.490005
# 2023-12-27    258.350006
# 2023-12-28    263.660004
# 2023-12-29    255.100006
# Name: Open, Length: 1006, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
#prevent overlapping
#plt.xticks(rotation=35)
figure.autofmt_xdate()
axis.plot(index, stock_open)

# %%
# Date time index

# %%
df_tesla = df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3452 entries, 0 to 3451
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3452 non-null   datetime64[ns]
#  1   Open       3452 non-null   float64
#  2   High       3452 non-null   float64
#  3   Low        3452 non-null   float64
#  4   Close      3452 non-null   float64
#  5   Adj Close  3452 non-null   float64
#  6   Volume     3452 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 188.9 KB

# %%
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3447 2024-03-11  175.449997  182.869995  174.800003  177.770004  177.770004
# 3448 2024-03-12  177.770004  179.429993  172.410004  177.539993  177.539993
# 3449 2024-03-13  173.050003  176.050003  169.149994  169.479996  169.479996
# 3450 2024-03-14  167.770004  171.169998  160.509995  162.500000  162.500000
# 3451 2024-03-15  163.160004  165.179993  160.759995  163.570007  163.570007
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df_tesla = df_tesla.set_index('Date', drop=True)

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
#datetime
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 3, 16, 9, 23, 57, 371314)

# %% [markdown]
# # **TIME SAMPLING**

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
# year and frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# quaterly start frequency
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Bussines End Frequency
df_tesla.resample(rule='BA').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# PLOTTING
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
# PLOTTING
plt.figure(figsize=(20,5))
df_tesla['Open'].resample(rule='M').max().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].rolling(10).mean()
# Out:
# Date
# 2010-06-29           NaN
# 2010-06-30           NaN
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
#                  ...
# 2024-03-11    193.225999
# 2024-03-12    190.608998
# 2024-03-13    187.683998
# 2024-03-14    184.272998
# 2024-03-15    180.338997
# Name: High, Length: 3452, dtype: float64

# %%
df_tesla['open: 30days rolling'] = df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(30)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[['Open','open: 30days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # TASK1

# %%
df_msft = yf.download('MSFT')
df_msft
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060163
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062311
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063386
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061774
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060700
# ...                ...         ...         ...         ...         ...
# 2024-03-11  403.760010  405.679993  401.260010  404.519989  404.519989
# 2024-03-12  407.619995  415.570007  406.790009  415.279999  415.279999
# 2024-03-13  418.100006  418.179993  411.450012  415.100006  415.100006
# 2024-03-14  420.239990  427.820007  417.989990  425.220001  425.220001
# 2024-03-15  419.290009  422.600006  412.790009  416.420013  416.420013
#
#                 Volume
# Date
# ...

# %%
df_msft.loc['2017-01-01':'2022-12-29']['Open'].resample(rule='A').plot(figsize=(12,5))
# Out:
# Date
# 2017-12-31    Axes(0.125,0.2;0.775x0.68)
# 2018-12-31    Axes(0.125,0.2;0.775x0.68)
# 2019-12-31    Axes(0.125,0.2;0.775x0.68)
# 2020-12-31    Axes(0.125,0.2;0.775x0.68)
# 2021-12-31    Axes(0.125,0.2;0.775x0.68)
# 2022-12-31    Axes(0.125,0.2;0.775x0.68)
# Freq: A-DEC, Name: Open, dtype: object

# %%
high = df_msft.loc['2017-01-01':'2022-12-29']

# %%
high.max()
# Out:
# Open         3.446200e+02
# High         3.496700e+02
# Low          3.422000e+02
# Close        3.431100e+02
# Adj Close    3.363153e+02
# Volume       1.112421e+08
# dtype: float64

# %%
high
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   62.790001   62.840000   62.130001   62.580002   57.033264
# 2017-01-04   62.480000   62.750000   62.119999   62.299999   56.778088
# 2017-01-05   62.189999   62.660000   62.029999   62.299999   56.778088
# 2017-01-06   62.299999   63.150002   62.040001   62.840000   57.270214
# 2017-01-09   62.759998   63.080002   62.540001   62.639999   57.087929
# ...                ...         ...         ...         ...         ...
# 2022-12-22  241.259995  241.990005  233.869995  238.190002  235.660751
# 2022-12-23  236.110001  238.869995  233.940002  238.729996  236.195007
# 2022-12-27  238.699997  238.929993  235.830002  236.960007  234.443817
# 2022-12-28  236.889999  239.720001  234.169998  234.529999  232.039612
# 2022-12-29  235.649994  241.919998  235.649994  241.009995  238.450790
#
#               Volume
# Date
# 2017-01-03  20694100
# 2017-01-04  21340000
# 2017-01-05  24876000
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# PLOTTING
df_msft['Open']['2017-01-01':'2022-12-29'].resample(rule='A').max().plot(kind='bar', figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# PLOTTING
df_msft['Open']['2017-01-01':'2022-12-29'].resample(rule='A').min().plot(kind='bar', figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>
